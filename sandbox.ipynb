# %%
import plotly.express as px
from dash import dcc
import pandas as pd
import geopandas as gpd

shape_file = "Cleaning/Datasets/zip_geojson.geojson"
geojson = gpd.read_file(shape_file)
geojson.plot(figsize=(20, 10))
# Out:
# <Axes: >

# %%
df = pd.read_csv("merged.csv")
fig = px.choropleth_mapbox(df, geojson=shape_file, locations="zip", featureidkey="properties.zip",
                           color="votingrates", mapbox_style="carto-positron", center={"lat":41.8, "lon": -87.75}
                   )
fig.update_geos(fitbounds="locations", visible=False)

# %%
fig2 = px.choropleth(df, geojson=shape_file, locations="zip", featureidkey="properties.zip", color="votingrates")
fig2.update_geos(fitbounds="locations", visible=False)

button1 =  dict(method = "restyle",
                args = [{'z': [ df["votingrates"] ] }],
                label = "Voting Rates")
button2 =  dict(method = "restyle",
                args = [{'z': [ df["complaintcounts"] ]}],
                label = "3-1-1 Complaints")

# TODO: Use dictionary to update title_text
fig2.update_layout(width=700,
                  coloraxis_colorbar_thickness=23,
                  coloraxis_colorbar_title_text=None,   
                  updatemenus=[dict(y=0.9,
                                    x=0.275,
                                    xanchor='right',
                                    yanchor='top',
                                    active=0,
                                    buttons=[button1, button2],
                                    )
                              ])

# %%
dcc.Graph(figure=fig)
# Out:
# Graph(figure=Figure({
#     'data': [{'coloraxis': 'coloraxis',
#               'featureidkey': 'properties.zip',
#               'geojson': 'Cleaning/Datasets/zip_geojson.geojson',
#               'hovertemplate': 'zip=%{location}<br>votingrates=%{z}<extra></extra>',
#               'locations': array([60601, 60602, 60603, 60604, 60605, 60606, 60607, 60608, 60609, 60610,
#                                   60611, 60612, 60613, 60614, 60615, 60616, 60617, 60618, 60619, 60620,
#                                   60621, 60622, 60623, 60624, 60625, 60626, 60628, 60629, 60630, 60631,
#                                   60632, 60633, 60634, 60636, 60637, 60638, 60639, 60640, 60641, 60642,
#                                   60643, 60644, 60645, 60646, 60647, 60649, 60651, 60652, 60653, 60654,
#                                   60655, 60656, 60657, 60659, 60660, 60661, 60707, 60827]),
#               'name': '',
#               'subplot': 'mapbox',
#               'type': 'choroplethmapbox',
#               'z': array([0.27308448, 0.27308448, 0.33408072, 0.33408072, 0.33408072, 0.33408072,
#                           0.21385902, 0.21385902, 0.28010139, 0.28010139, 0.28010139, 0.3954727 ,
#                           0.3954727 , 0.37269939, 0.37269939, 0.28571429, 0.25794155, 0.29279279,
#                           0.2755814 , 0.2755814 , 0.27121001, 0.27121001, 0.31274639, 0.31274639,
#                           0.26426077, 0.24441524, 0.24441524, 0.24441524, 0.24441524, 0.28237792,
#                           0.28237792, 0.26857888, 0.26857888, 0.26857888, 0.28286853, 0.28286853,
#                           0.28286853, 0.28286853, 0.4704    , 0.4704    , 0.45081967, 0.45081967,
#                           0.25648022, 0.36962366, 0.36962366, 0.33199465, 0.33215548, 0.33215548,
#                           0.35350757, 0.35350757, 0.24892086, 0.24892086, 0.27883212, 0.27883212,
#                           0.27883212, 0.23399015, 0.22845417, 0.22845417])}],
#     'layout': {'coloraxis': {'colorbar': {'title': {'text': 'votingrates'}},
#                              'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'geo': {'fitbounds': 'locations', 'visible': False},
#                'legend': {'tracegroupgap': 0},
#                'mapbox': {'center': {'lat': 41.8, 'lon': -87.75},
#                           'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#                           'style': 'carto-positron',
#                           'zoom': 8},
#                'margin': {'t': 60},
#                'template': '...'}
# }))
